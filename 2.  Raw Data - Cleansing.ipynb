# %%
import csv
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import plotly.express as px
from datetime import date
from collections import Counter

# %%
# Read CSV file into DataFrame sss (results from the dba sql server survey)

sss = pd.read_csv('Data/sqlserver_survey_raw.csv')

# %%
sss.head(1)
# Out:
#           Timestamp  \
# 0  12/10/2017 12:44
#
#    What’s your total salary in US dollars, ANNUAL BEFORE TAXES?  \
# 0                                             115000
#
#     Your country Zipcode      Primary database  Years of experience with DB  \
# 0  United States   84095  Microsoft SQL Server                           15
#
#                Other databases             Job type  \
# 0  MySQL/MariaDB, Elasticsearch  Full time employee
#
#                                            Job title  \
# 0  DBA (General - splits time evenly between writ...
#
#   Do you manage other staff?  ...  Is your college degree computer-related?  \
# 0                         No  ...                                        No
#
#   Do you hold industry certifications?  How many hours do you work per week?  \
# 0     Yes, and they're currently valid                                    40
#
#   Number of days do you work from home?   Employer sector  \
# ...

# %%
#  Rename Column Names 

sss.rename(columns={'Timestamp':'TStamp', 'What’s your total salary in US dollars, ANNUAL BEFORE TAXES?':'Salary', 'Your country':'Country', 'Primary database':'Primary_DB', 'Years of experience with DB':'Pdb_YearsExp', 'Other databases':'Other_DB', 'Job type':'Job_Type', 'Job title':'Job_Title', 'Do you manage other staff?':'Manager', 'Is your college degree computer-related?':'CS_Degree', 'Do you hold industry certifications?':'Certifications', 'How many hours do you work per week?':'Hours_Worked_Per_Week', 'Number of days do you work from home?':'Days_WFH', 'Employer sector':'Employer_Sector', 'Are you looking for another job right now?':'Job_Search', 'What are your career plans for the year 2018?':'Career_Plan_CurrentYear', 'To which gender do you most identify?	Other job ':'Gender', 'Other job duties':'Other_Duties', 'What kinds of work do you do?':'Primary_Role'}, inplace = True)

# %%
sss
# Out:
#                 TStamp  Salary        Country Zipcode            Primary_DB  \
# 0     12/10/2017 12:44  115000  United States   84095  Microsoft SQL Server
# 1     12/10/2017 22:03   95000      Australia    7000  Microsoft SQL Server
# 2      12/11/2017 2:28   60000          Spain   28080  Microsoft SQL Server
# 3      12/11/2017 8:00   49000  United States   75904  Microsoft SQL Server
# 4      12/11/2017 8:52  156000  United States    1463  Microsoft SQL Server
# ...                ...     ...            ...     ...                   ...
# 3109    1/6/2018 14:09  160000  United States   94063         MySQL/MariaDB
# 3110    1/6/2018 15:07   50000         France   33000  Microsoft SQL Server
# 3111     1/7/2018 0:46  119000  United States   15234  Microsoft SQL Server
# 3112     1/7/2018 9:48   65000         Greece     NaN  Microsoft SQL Server
# 3113   3/20/2018 11:42  117000  United States   80132  Microsoft SQL Server
#
# ...
